# %%
import turtle
import math
t = turtle.Turtle()
canh = int(input("nhap chieu dai mot canh: "))
t.pencolor('blue')
t.pensize(2)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(72)
turtle.done()
# Out:
# nhap chieu dai mot canh: 100
